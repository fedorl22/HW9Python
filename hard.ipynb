# %% [markdown]
# <a href="https://colab.research.google.com/github/fedorl22/HW9Python/blob/main/hard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Импорты

# %%
# Библиотека для работы с табличными данными
import pandas as pd
import seaborn as sns

# %% [markdown]
# **привет**

# %% [markdown]
# # Чтение и предварительный просмотр данных

# %% [markdown]
# Библиотека **pandas** может читать многие форматы, включая: **.csv, .xslx, .xls, .txt, sql** и многие другие.
#
# Полный список по [ссылке](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)

# %%
# Прочтем файл .csv с помощью библиотеки pandas

df = pd.read_csv('sample_data/cwurData.csv')

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
# Посмотреть есть ли у нас пустые значения
# В данном случае пустых значений нет
df.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
# Проверить тип данных в столбцах
# В данных случаях везде float, число 64 указывает на разрядность(Используется 64 байта для хранения значения в памяти,
# чем меньше разрядность, тем меньший диапазон могут принимать числа и тем меньше тратится памяти на хранение.
df.dtypes
# Out:
# world_rank                int64
# institution              object
# country                  object
# national_rank             int64
# quality_of_education      int64
# alumni_employment         int64
# quality_of_faculty        int64
# publications              int64
# influence                 int64
# citations                 int64
# broad_impact            float64
# patents                   int64
# score                   float64
# year                      int64
# dtype: object

# %%
# Посмотреть все столбцы
# Возвращает список со строками строк - названиями столбцов в таблице
df.columns
# Out:
# Index(['world_rank', 'institution', 'country', 'national_rank',
#        'quality_of_education', 'alumni_employment', 'quality_of_faculty',
#        'publications', 'influence', 'citations', 'broad_impact', 'patents',
#        'score', 'year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %%
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
df[  (df['quality_of_education'] > 366)   ]
# Out:
#       world_rank                              institution       country  \
# 1223          24                Seoul National University   South Korea
# 1225          26  University of California, San Francisco           USA
# 1264          65         National University of Singapore     Singapore
# 1281          82           Katholieke Universiteit Leuven       Belgium
# 1283          84                         Emory University           USA
# ...          ...                                      ...           ...
# 2194         995                King Abdulaziz University  Saudi Arabia
# 2195         996                University of the Algarve      Portugal
# 2197         998              Federal University of Ceará        Brazil
# 2198         999                   University of A Coruña         Spain
# 2199        1000          China Pharmaceutical University         China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df[(df['quality_of_education'] > 366) & (df['country'] != 'USA'	)]
# Out:
#       world_rank                                        institution  \
# 1223          24                          Seoul National University
# 1264          65                   National University of Singapore
# 1281          82                     Katholieke Universiteit Leuven
# 1284          85                       Erasmus University Rotterdam
# 1290          91  Swiss Federal Institute of Technology in Lausanne
# ...          ...                                                ...
# 2194         995                          King Abdulaziz University
# 2195         996                          University of the Algarve
# 2197         998                        Federal University of Ceará
# 2198         999                             University of A Coruña
# 2199        1000                    China Pharmaceutical University
#
#            country  national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df.loc[     df['publications'] > 950]
# Out:
#       world_rank                            institution      country  \
# 366          167                        Mines ParisTech       France
# 506          307                    Wesleyan University          USA
# 712          513                     Dongguk University  South Korea
# 722          523                   École Centrale Paris       France
# 737          538                   University of Dayton          USA
# ...          ...                                    ...          ...
# 2187         988                    Mansoura University        Egypt
# 2188         989  University of Pau and Pays de l'Adour       France
# 2189         990                Henan Normal University        China
# 2191         992            Federal University of Bahia       Brazil
# 2196         997                  Alexandria University        Egypt
#
#       national_rank  quality_of_education  alumni_employment  \
# 366               6                   249                 31
# ...

# %%
df.loc[     df['world_rank'] < 10]
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# 5              6                   Princeton University             USA
# 6              7                   University of Oxford  United Kingdom
# 7              8                        Yale University             USA
# 8              9                    Columbia University             USA
# 100            1                     Harvard University             USA
# 101            2                    Stanford University             USA
# 102            3                   University of Oxford  United Kingdom
# ...

# %%
df[(df['patents'] > 800) & (df['country'] != 'USA'	)]
# Out:
#       world_rank                        institution       country  \
# 1236          37   École normale supérieure - Paris        France
# 1258          59  Lomonosov Moscow State University        Russia
# 1303         104                    Mines ParisTech        France
# 1316         117                    Lund University        Sweden
# 1323         124                 Uppsala University        Sweden
# ...          ...                                ...           ...
# 2192         993      Southwest Jiaotong University         China
# 2194         995          King Abdulaziz University  Saudi Arabia
# 2195         996          University of the Algarve      Portugal
# 2196         997              Alexandria University         Egypt
# 2197         998        Federal University of Ceará        Brazil
#
#       national_rank  quality_of_education  alumni_employment  \
# 1236              2                     8                502
# ...

# %%
# Максимальное значение
print(df['patents'].max())
print(df['publications'].max())
# Минимальное значение
print(df['patents'].min())
print(df['publications'].min())
# Среднее значение
print(df['patents'].mean())
print(df['publications'].mean())
print(df['patents'].median())
print(df['publications'].median())

# Сумма
print(df['patents'].sum())
print(df['publications'].sum())
# Out:
# 871
# 1000
# 1
# 1
# 433.34636363636366
# 459.9086363636364
# 426.0
# 450.5
# 953362
# 1011799

# %%
# Медианное значение
df[['patents', 'publications']].median()
# Out:
# patents         426.0
# publications    450.5
# dtype: float64

# %%
def norm_patents(patents):
  return patents/10
df['publications'] = df['publications'].apply(norm_patents)

# %%
#@title Текст заголовка по умолчанию
variable_name = ""
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
#@title При высоком качестве образования растет рейтинг и количество публикаций.
sns.scatterplot(data = df, x='quality_of_education', y='publications', hue='world_rank' )

# %%
sns.scatterplot(data = df, x='patents', y='publications', hue='year' )

# %%
cols = ['patents', 'publications', 'national_rank', 'year']
g = sns.PairGrid(df[cols])
g.map(sns.scatterplot)

# %%
sns.scatterplot(data = df, x='patents', y='publications')
